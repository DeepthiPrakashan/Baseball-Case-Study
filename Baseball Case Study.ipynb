# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors

# %%
Baseball = pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
Baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
Baseball.shape
# Out:
# (30, 17)

# %%
Baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
Baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No null values are present

# %%
Baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# ## Data Vizualization

# %%
Top_teams = Baseball.sort_values(by=['W'],ascending= False)

# %%
Top_teams.plot(y='W',kind= 'bar', color= 'green',figsize=(20,6))
plt.title('Total number of Wins by each Team')               
plt.xlabel('Teams',)
plt.ylabel('Wins')
plt.show()

# %%
#Number of wins in top10 teams

Top10 =Top_teams[:10]
Top10['W']
# Out:
# 15    100
# 16     98
# 17     97
# 0      95
# 5      93
# 25     92
# 20     90
# 10     88
# 6      87
# 11     86
# Name: W, dtype: int64

# %%
#Vizualising the distribution

sns.distplot(Baseball['W'],kde=True)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
plt.figure(figsize=(13,5))

Top_teams['CG'].plot( kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Distribution of the data

# %%
#Distribution of the data
plt.figure(figsize =(20,25), facecolor='white')
plotnumber = 1

for column in Baseball :
    if plotnumber <= 17:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(Baseball[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber +=1
plt.show()

# %%
Baseball.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# There seems some skewness in our data which we will try to remove in the preprocessing step

# %% [markdown]
# ### Vizualising the replationship between features and target

# %%
plt.figure(figsize =(20,25), facecolor='white')
plotnumber = 1

for column in Baseball:
    if plotnumber <= 17:
        ax = plt.subplot(6,3,plotnumber)
        sns.regplot(y=Baseball['W'],x= Baseball[column])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('W',fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# Positive correlation :There is a a positive relationship between Win and Saves(SV)
# Negative correlation: seen between RA-Win,Er-Win,ERA-Win

# %% [markdown]
# ## Correlation

# %%
Baseball.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=Baseball.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# On analyzing the heatmap, there are few cases where the collinearity is high between the features such as RA and ERA, RA and ER, HR and R, AB and H.
# We need to analyse further to see if its a case of mullticollinearity or not. If it is we would require to drop few of the features.

# %%
Baseball.drop('W',axis= 1).corrwith(Baseball.W).sort_values(ascending= False)
# Out:
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# dtype: float64

# %% [markdown]
# #### Visualise the correlation

# %%
Baseball.drop('W',axis= 1).corrwith(Baseball.W).sort_values(ascending= False).plot(kind='bar', figsize = (10,7))
plt.show()

# %% [markdown]
# Here we can study the features that share correlation with the target. As obsevered earlier in regplot, Saves share the highest positive correlation and ERA highest negative correlation. Hits seems to contribute less to Wins as its value is close to 0.

# %% [markdown]
# ## Checking for outliers

# %%
plt.figure(figsize =(20,25), facecolor='white')
plotnumber = 1

for column in Baseball :
    if plotnumber <= 17:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(Baseball[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber +=1
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Removing outliers

# %%
from scipy.stats import zscore

# %%
f=Baseball[['R','ERA', 'SHO', 'SV', 'E']]

# %%
z=np.abs(zscore(f))

# %%
df=Baseball[(z<3).all(axis=1)]
df.shape
# Out:
# (29, 17)

# %%
plt.figure(figsize =(20,25), facecolor='white')
plotnumber = 1

for column in df :
    if plotnumber <= 17:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    
    plotnumber +=1
plt.show()

# %% [markdown]
# - we have removed the outliers whose zscore is less than 3

# %%
X=df.drop(['W','H'],axis=1)

# %%
y=df['W']

# %%
X.skew()
# Out:
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# - skewness needs to be treated as we can see values greater than +/-0.5

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer()

# %%
i = [ 'CG', 'SHO', 'SV', 'E']
X[i]= scaler.fit_transform(X[i].values)
X.skew()
# Out:
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# - skewness is mostly treated

# %% [markdown]
# ### Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_scaled= scalar.fit_transform(X)
X_scaled= pd.DataFrame(X_scaled,columns=X.columns)
X_scaled
# Out:
#            R        AB        2B        3B        HR        BB        SO  \
# 0   0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 6   0.712585 -0.447345 -1.625627 -1.167936  1.915843 -0.885522  0.777970
# 7  -0.835605 -0.447345  0.260100  0.020490  0.196801 -0.550807  0.572335
# 8   1.497899  1.752672  1.202964  0.119526 -0.009484  0.230197 -1.013995
# 9   1.565212 -0.078310  0.319029  0.020490  0.368705  0.695081 -0.181661
# 10  1.071586 -0.816380  0.260100 -0.573723  2.362794  0.378960  1.375292
# 11 -0.454167 -1.412514 -1.802414 -1.068901  0.506228 -0.569402 -0.994411
# 12 -0.566355  0.390081 -0.682763 -0.969865  1.262607  0.230197  0.826931
# 13  0.286272  1.184926  0.201171  1.406988 -0.525197  0.174411 -1.297968
# 14 -0.768292 -0.461539  0.849390  0.713739 -0.834625  0.750867  0.151272
# 15  0.353585  1.624929  1.085106 -0.474688 -0.731482 -0.085923  0.689841
# 16  0.174084 -0.362183 -0.093474 -0.177581  0.334324  1.885182  2.609104
# 17 -0.588792 -0.518313  0.024384  0.218561 -0.559578 -0.997094  0.464621
# 18 -0.925355  0.773310 -0.977408 -0.474688  0.196801  0.564913  0.033766
# 19  0.039459  0.148789  1.261893 -1.465043  0.540609  0.416151  0.376492
# 20  0.488210 -1.256383 -0.505976 -1.861185  0.540609  1.364512  0.905268
# 21 -1.531169 -0.759605 -2.214917  0.812774 -1.419099 -1.685122 -0.994411
# 22 -2.428670 -1.369933 -1.330982 -1.366007 -2.106716  0.100030 -1.415474
# 23 -1.239481  0.177176 -0.093474  0.515668 -1.075291 -1.461978  0.219817
# 24 -0.319542 -1.866711 -0.623834 -0.573723  0.884418  1.810800  0.063143
# 25  0.331147  0.688148  0.849390  0.713739 -0.869006 -0.160305 -0.906281
# 26  0.869648  1.880415  0.908319  1.605059 -0.250150  0.453341  0.591919
# 27 -0.700980 -0.844767 -0.800621  0.416632 -0.456435 -0.736760  0.738802
# 28  1.251086  0.787503  0.024384  1.704094  0.850037 -1.443382  0.307947
#
#           SB        RA        ER       ERA        CG       SHO        SV  \
# 0   0.905953 -0.664514 -0.511148 -0.511388 -0.307098 -0.787002  1.532753
# 1  -0.585315  0.154638  0.232161  0.238952 -0.307098  0.236737  0.312020
# 2   0.116458 -0.678397 -0.754153 -0.643801  2.011315 -0.252844 -0.664137
# 3  -0.673037  0.168522  0.089217  0.040333  1.264463 -0.513555 -0.820689
# 4  -0.015124  1.584683  1.561540  1.496876  1.264463  0.236737 -1.149165
# 5  -0.892341  0.126870  0.217866  0.150677  0.121871 -2.064039  0.677176
# 6  -1.725697  0.057451  0.132100  0.194815 -1.732896 -0.252844  0.052325
# 7   0.160319 -0.650630 -0.468265 -0.489319 -0.870682  0.236737  1.908137
# 8  -0.541454  0.890486  0.818231  0.768604  0.121871 -0.252844 -0.365006
# 9   0.774370  0.612808  0.618110  0.614123  0.770649 -0.513555  0.312020
# 10  1.651587 -0.983844 -0.925686 -0.864490  0.770649  0.468029 -0.512328
# 11 -1.374810 -0.192460 -0.096610 -0.047943 -0.307098  0.236737  0.436838
# 12 -0.629176  0.515620  0.575226  0.437572  1.031663  0.236737  0.312020
# 13 -0.234429  0.557272  0.389399  0.393434  0.770649  0.908147 -2.498840
# 14 -0.629176 -2.275049 -2.269360 -2.254827 -0.870682  0.908147  2.084917
# 15  0.642788 -1.289290 -1.497462 -1.658968 -1.732896  0.468029  1.333006
# 16  0.511205 -1.122683 -1.297340 -1.327935  1.031663  2.090856  0.677176
# 17  0.028736  0.668344  0.646698  0.702398 -0.870682 -1.075340 -0.365006
# 18  2.221778  0.904370  0.903998  0.812742 -0.307098 -0.787002 -1.149165
# 19 -1.418671 -1.053264 -1.140102 -1.173453 -0.870682  0.691583  0.906024
# 20 -1.155506 -0.747817 -0.854214 -0.754146  0.472300  0.468029 -0.221934
# 21  1.256840 -0.150808  0.017745  0.128608 -1.732896  0.236737 -1.149165
# 22 -0.629176  0.987674  0.875409  0.989293  0.121871 -0.252844  0.183904
# 23  0.204180  1.667986  1.604423  1.607220 -0.870682 -1.075340 -1.149165
# 24 -1.067784 -1.303174 -1.197279 -1.151385  1.031663  2.090856  0.558509
# 25  0.423484 -0.858889 -0.568326 -0.533457  1.264463  1.521828 -0.221934
# 26  2.134056  0.335129  0.317927  0.172746 -0.870682  0.236737  0.183904
# 27 -0.058985  0.585040  0.260750  0.283090 -0.870682 -1.381412 -0.221934
# 28  0.598927  2.153924  2.319144  2.379630  0.472300 -2.064039 -0.982264
#
#            E
# 0  -0.348265
# 1  -0.540820
# 2  -1.326125
# 3   0.650818
# 4  -0.540820
# 5   0.082858
# 6  -1.588197
# 7   0.237592
# 8   0.383386
# 9   1.554265
# 10 -0.641926
# 11  0.082858
# 12  0.161388
# 13  1.810553
# 14  0.311562
# 15  1.669209
# 16  1.203715
# 17  1.430810
# 18 -0.167685
# 19 -0.348265
# 20 -0.167685
# 21 -1.588197
# 22 -0.167685
# 23  1.472959
# 24 -1.870191
# 25 -1.454792
# 26 -0.540820
# 27  0.001905
# 28  0.237592

# %%
x= X_scaled

# %% [markdown]
# ## Training the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
#Finding the best random state

MaxAcc = 0
MaxRS =0
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    predlr_train= lr.predict(x_train)
    predlr_test= lr.predict(x_test)
    acc= r2_score(y_test,predlr_test)
    
    if acc>MaxAcc:
        MaxAcc=acc
        MaxRS= i
    print(f'At random state {i}, the training accuracy is: {r2_score(y_train,predlr_train)}')
    print(f'At random state {i}, the testing accuracy is: {r2_score(y_test,predlr_test)}')
    print('/n')
# Out:
# At random state 1, the training accuracy is: 0.9827010207558656
# At random state 1, the testing accuracy is: 0.3915021015808371
# /n
# At random state 2, the training accuracy is: 0.9590166646445036
# At random state 2, the testing accuracy is: 0.28435792717158126
# /n
# At random state 3, the training accuracy is: 0.9697049838353198
# At random state 3, the testing accuracy is: 0.6126073903077549
# /n
# At random state 4, the training accuracy is: 0.9799608718217943
# At random state 4, the testing accuracy is: -4.511564805946495
# /n
# At random state 5, the training accuracy is: 0.9669278321461263
# At random state 5, the testing accuracy is: 0.6111737921155496
# /n
# At random state 6, the training accuracy is: 0.9740709739050545
# At random state 6, the testing accuracy is: 0.7171960789047088
# /n
# At random state 7, the training accuracy is: 0.9642562195327279
# At random state 7, the testing accuracy is: 0.13973700698451552
# /n
# At random state 8, the training accuracy is: 0.9684143610256382
# At random state 8, the testing accuracy is: 0.8294377420115501
# /n
# At random state 9, the training accuracy is: 0.9794170250111056
# At random state 9, the testing accuracy is: 0.7083555922197324
# /n
# At random state 10, the training accuracy is: 0.9932406050560144
# At random state 10, the testing accuracy is: -0.1972546398845587
# /n
# At random state 11, the training accuracy is: 0.9792917458502323
# At random state 11, the testing accuracy is: 0.02693529136481776
# /n
# At random state 12, the training accuracy is: 0.9736210890459661
# At random state 12, the testing accuracy is: 0.7562884466327902
# /n
# At random state 13, the training accuracy is: 0.9785560810826508
# At random state 13, the testing accuracy is: 0.6907049574652362
# /n
# At random state 14, the training accuracy is: 0.9701105592047298
# At random state 14, the testing accuracy is: 0.05699369061607995
# /n
# At random state 15, the training accuracy is: 0.9828165481926481
# At random state 15, the testing accuracy is: 0.604132050011933
# /n
# At random state 16, the training accuracy is: 0.9943898670364516
# At random state 16, the testing accuracy is: -0.6790926548638836
# /n
# At random state 17, the training accuracy is: 0.9598522103666363
# At random state 17, the testing accuracy is: 0.76047624403875
# /n
# At random state 18, the training accuracy is: 0.9856763224117925
# At random state 18, the testing accuracy is: -0.12757625423899754
# /n
# At random state 19, the training accuracy is: 0.9661762256688708
# At random state 19, the testing accuracy is: 0.7343813577328409
# /n
# At random state 20, the training accuracy is: 0.9694300265605009
# At random state 20, the testing accuracy is: 0.14230142449262306
# /n
# At random state 21, the training accuracy is: 0.9933777205458701
# At random state 21, the testing accuracy is: -3.1996081406700494
# /n
# At random state 22, the training accuracy is: 0.9603619051035962
# At random state 22, the testing accuracy is: 0.6375346747233532
# /n
# At random state 23, the training accuracy is: 0.9837054974120935
# At random state 23, the testing accuracy is: 0.7581076803471498
# /n
# At random state 24, the training accuracy is: 0.9939116914622734
# At random state 24, the testing accuracy is: -1.0925177646242639
# /n
# At random state 25, the training accuracy is: 0.9732849818368581
# At random state 25, the testing accuracy is: -1.8656708793532233
# /n
# At random state 26, the training accuracy is: 0.9745244841358645
# At random state 26, the testing accuracy is: 0.0648325173243206
# /n
# At random state 27, the training accuracy is: 0.981766084216794
# At random state 27, the testing accuracy is: 0.7715603313474662
# /n
# At random state 28, the training accuracy is: 0.9827818724075068
# At random state 28, the testing accuracy is: 0.6431755624070643
# /n
# At random state 29, the training accuracy is: 0.9747055372180965
# At random state 29, the testing accuracy is: -1.615377185926917
# /n
# At random state 30, the training accuracy is: 0.954025859535189
# At random state 30, the testing accuracy is: 0.6831308038611839
# /n
# At random state 31, the training accuracy is: 0.9816823895886676
# At random state 31, the testing accuracy is: 0.4073027926884688
# /n
# At random state 32, the training accuracy is: 0.9793963470318283
# At random state 32, the testing accuracy is: 0.353472304975602
# /n
# At random state 33, the training accuracy is: 0.9730287664851855
# At random state 33, the testing accuracy is: 0.6829129109642241
# /n
# At random state 34, the training accuracy is: 0.96896853747181
# At random state 34, the testing accuracy is: 0.7636050011019901
# /n
# At random state 35, the training accuracy is: 0.979249087507318
# At random state 35, the testing accuracy is: 0.7160030165200926
# /n
# At random state 36, the training accuracy is: 0.9776353351793
# At random state 36, the testing accuracy is: 0.3770756145005165
# /n
# At random state 37, the training accuracy is: 0.9860161130447317
# At random state 37, the testing accuracy is: 0.3042445486418237
# /n
# At random state 38, the training accuracy is: 0.9807828948294359
# At random state 38, the testing accuracy is: -1.0213338316452174
# /n
# At random state 39, the training accuracy is: 0.971062919534765
# At random state 39, the testing accuracy is: 0.3810083891367885
# /n
# At random state 40, the training accuracy is: 0.9873150341545027
# At random state 40, the testing accuracy is: 0.013529687790445943
# /n
# At random state 41, the training accuracy is: 0.9808786777480261
# At random state 41, the testing accuracy is: 0.6625872979071951
# /n
# At random state 42, the training accuracy is: 0.9678158915279702
# At random state 42, the testing accuracy is: 0.743670239343097
# /n
# At random state 43, the training accuracy is: 0.9832751763339537
# At random state 43, the testing accuracy is: 0.01535048227952085
# /n
# At random state 44, the training accuracy is: 0.9801729961859532
# At random state 44, the testing accuracy is: 0.44126469274618174
# /n
# At random state 45, the training accuracy is: 0.9884660485386961
# At random state 45, the testing accuracy is: -1.6075459302878428
# /n
# At random state 46, the training accuracy is: 0.9646607140274142
# At random state 46, the testing accuracy is: 0.6123082496035208
# /n
# At random state 47, the training accuracy is: 0.9900430817956493
# At random state 47, the testing accuracy is: -2.388743379303731
# /n
# At random state 48, the training accuracy is: 0.9882554041635706
# At random state 48, the testing accuracy is: -0.3824630354385721
# /n
# At random state 49, the training accuracy is: 0.9818194148554313
# At random state 49, the testing accuracy is: -0.12380845510106608
# /n
# At random state 50, the training accuracy is: 0.954041110059842
# At random state 50, the testing accuracy is: 0.7959498538479681
# /n
# At random state 51, the training accuracy is: 0.9799640192386609
# At random state 51, the testing accuracy is: 0.23091912023829064
# /n
# At random state 52, the training accuracy is: 0.9889030131911216
# At random state 52, the testing accuracy is: 0.2709290608392366
# /n
# At random state 53, the training accuracy is: 0.972871767918234
# At random state 53, the testing accuracy is: 0.36566311201497637
# /n
# At random state 54, the training accuracy is: 0.9852283080585971
# At random state 54, the testing accuracy is: -0.049664382480752334
# /n
# At random state 55, the training accuracy is: 0.9826543178565388
# At random state 55, the testing accuracy is: -0.2057860375215792
# /n
# At random state 56, the training accuracy is: 0.9890583253529885
# At random state 56, the testing accuracy is: -0.3331031825221151
# /n
# At random state 57, the training accuracy is: 0.9745996049948499
# At random state 57, the testing accuracy is: 0.5117012551126938
# /n
# At random state 58, the training accuracy is: 0.9838046930369312
# At random state 58, the testing accuracy is: 0.6954826636093623
# /n
# At random state 59, the training accuracy is: 0.9731755492020557
# At random state 59, the testing accuracy is: 0.6685266099068887
# /n
# At random state 60, the training accuracy is: 0.988428148942127
# At random state 60, the testing accuracy is: 0.5217508980825883
# /n
# At random state 61, the training accuracy is: 0.982924747981853
# At random state 61, the testing accuracy is: 0.6168769632176425
# /n
# At random state 62, the training accuracy is: 0.9775285445191905
# At random state 62, the testing accuracy is: 0.8146788943631373
# /n
# At random state 63, the training accuracy is: 0.9814351131323623
# At random state 63, the testing accuracy is: 0.6562744973218924
# /n
# At random state 64, the training accuracy is: 0.9933495608229999
# At random state 64, the testing accuracy is: 0.46184657735648027
# /n
# At random state 65, the training accuracy is: 0.9767292826928557
# At random state 65, the testing accuracy is: 0.503006272183613
# /n
# At random state 66, the training accuracy is: 0.9569926257898165
# At random state 66, the testing accuracy is: 0.6873030567311504
# /n
# At random state 67, the training accuracy is: 0.9594017410817909
# At random state 67, the testing accuracy is: 0.6480390522281213
# /n
# At random state 68, the training accuracy is: 0.9704952882474323
# At random state 68, the testing accuracy is: 0.45224530568463417
# /n
# At random state 69, the training accuracy is: 0.9852760734956479
# At random state 69, the testing accuracy is: 0.26422429571530004
# /n
# At random state 70, the training accuracy is: 0.9804336512893608
# At random state 70, the testing accuracy is: 0.44409219959004975
# /n
# At random state 71, the training accuracy is: 0.9949375303098983
# At random state 71, the testing accuracy is: -0.891028109150646
# /n
# At random state 72, the training accuracy is: 0.9839925720055231
# At random state 72, the testing accuracy is: -4.4376397073617
# /n
# At random state 73, the training accuracy is: 0.9611257539441322
# At random state 73, the testing accuracy is: 0.6497954363546239
# /n
# At random state 74, the training accuracy is: 0.9944769583939624
# At random state 74, the testing accuracy is: -0.2664328534628644
# /n
# At random state 75, the training accuracy is: 0.9738727335277757
# At random state 75, the testing accuracy is: -0.19868876048661965
# /n
# At random state 76, the training accuracy is: 0.9661793714616418
# At random state 76, the testing accuracy is: 0.7234415768243307
# /n
# At random state 77, the training accuracy is: 0.9730651159523401
# At random state 77, the testing accuracy is: -0.45252440585492115
# /n
# At random state 78, the training accuracy is: 0.9601633788190945
# At random state 78, the testing accuracy is: 0.5523028758509156
# /n
# At random state 79, the training accuracy is: 0.9790156363801933
# At random state 79, the testing accuracy is: 0.1474159904012352
# /n
# At random state 80, the training accuracy is: 0.9963733290031278
# At random state 80, the testing accuracy is: -1.088615139641092
# /n
# At random state 81, the training accuracy is: 0.9746866929960223
# At random state 81, the testing accuracy is: 0.7140607216310835
# /n
# At random state 82, the training accuracy is: 0.9935874285940308
# At random state 82, the testing accuracy is: -0.8069526885329434
# /n
# At random state 83, the training accuracy is: 0.973787990983303
# At random state 83, the testing accuracy is: 0.3771702914008872
# /n
# At random state 84, the training accuracy is: 0.9846302291808723
# At random state 84, the testing accuracy is: -1.653953529846405
# /n
# At random state 85, the training accuracy is: 0.9613644138612409
# At random state 85, the testing accuracy is: -0.017901785260509007
# /n
# At random state 86, the training accuracy is: 0.9803325202388132
# At random state 86, the testing accuracy is: -0.34864272335578916
# /n
# At random state 87, the training accuracy is: 0.9863929425643774
# At random state 87, the testing accuracy is: 0.30055854859636066
# /n
# At random state 88, the training accuracy is: 0.9917254955597982
# At random state 88, the testing accuracy is: -0.2338132378567952
# /n
# At random state 89, the training accuracy is: 0.9847683712225552
# At random state 89, the testing accuracy is: -0.010717811860115223
# /n
# At random state 90, the training accuracy is: 0.9759135522385012
# At random state 90, the testing accuracy is: 0.45145753342950823
# /n
# At random state 91, the training accuracy is: 0.993681894460704
# At random state 91, the testing accuracy is: 0.4202310531447415
# /n
# At random state 92, the training accuracy is: 0.992775346044461
# At random state 92, the testing accuracy is: 0.4146243878353675
# /n
# At random state 93, the training accuracy is: 0.9741962047334345
# At random state 93, the testing accuracy is: -1.555439567238873
# /n
# At random state 94, the training accuracy is: 0.9744918794790032
# At random state 94, the testing accuracy is: 0.7140813578625238
# /n
# At random state 95, the training accuracy is: 0.9780350816899409
# At random state 95, the testing accuracy is: 0.5125245362344768
# /n
# At random state 96, the training accuracy is: 0.9935094378186586
# At random state 96, the testing accuracy is: -0.9444922541805492
# /n
# At random state 97, the training accuracy is: 0.9552951870895364
# At random state 97, the testing accuracy is: 0.3969038861392493
# /n
# At random state 98, the training accuracy is: 0.9894546396211623
# At random state 98, the testing accuracy is: -1.176401809873358
# /n
# At random state 99, the training accuracy is: 0.9549130395913465
# At random state 99, the testing accuracy is: 0.6924046826452925
# /n
# At random state 100, the training accuracy is: 0.9939170112617723
# At random state 100, the testing accuracy is: -16.52458495021918
# /n
# At random state 101, the training accuracy is: 0.9913574247809352
# At random state 101, the testing accuracy is: -2.965469093439039
# /n
# At random state 102, the training accuracy is: 0.9665598035998564
# At random state 102, the testing accuracy is: -0.3191930081137824
# /n
# At random state 103, the training accuracy is: 0.9802520940177627
# At random state 103, the testing accuracy is: 0.712136603967075
# /n
# At random state 104, the training accuracy is: 0.9558520363212761
# At random state 104, the testing accuracy is: 0.8292648436039459
# /n
# At random state 105, the training accuracy is: 0.9823108103769481
# At random state 105, the testing accuracy is: 0.3177917665689498
# /n
# At random state 106, the training accuracy is: 0.9552686346780442
# At random state 106, the testing accuracy is: 0.882515544757087
# /n
# At random state 107, the training accuracy is: 0.9904647024063131
# At random state 107, the testing accuracy is: 0.40465902228450024
# /n
# At random state 108, the training accuracy is: 0.9889267122189138
# At random state 108, the testing accuracy is: 0.16507174935123803
# /n
# At random state 109, the training accuracy is: 0.9850481360332575
# At random state 109, the testing accuracy is: 0.09194796997447763
# /n
# At random state 110, the training accuracy is: 0.9918477358264634
# At random state 110, the testing accuracy is: -0.1196131834761458
# /n
# At random state 111, the training accuracy is: 0.9842650616207649
# At random state 111, the testing accuracy is: 0.18514368766789913
# /n
# At random state 112, the training accuracy is: 0.9817232523871896
# At random state 112, the testing accuracy is: -5.092353977983709
# /n
# At random state 113, the training accuracy is: 0.9929803925628614
# At random state 113, the testing accuracy is: -0.8014679657183637
# /n
# At random state 114, the training accuracy is: 0.9689634048360556
# At random state 114, the testing accuracy is: 0.6768731822806018
# /n
# At random state 115, the training accuracy is: 0.9959048087616217
# At random state 115, the testing accuracy is: -1.11774221854275
# /n
# At random state 116, the training accuracy is: 0.9775818459788176
# At random state 116, the testing accuracy is: 0.5864920938753547
# /n
# At random state 117, the training accuracy is: 0.9870197099082547
# At random state 117, the testing accuracy is: 0.24372022997012022
# /n
# At random state 118, the training accuracy is: 0.995261629478451
# At random state 118, the testing accuracy is: -1.9322645447295232
# /n
# At random state 119, the training accuracy is: 0.9686348972713459
# At random state 119, the testing accuracy is: 0.3672365897099349
# /n
# At random state 120, the training accuracy is: 0.9963292766643496
# At random state 120, the testing accuracy is: -3.67410800855835
# /n
# At random state 121, the training accuracy is: 0.9658374495757374
# At random state 121, the testing accuracy is: 0.7158974029347946
# /n
# At random state 122, the training accuracy is: 0.9819865046095155
# At random state 122, the testing accuracy is: 0.0971401068099701
# /n
# At random state 123, the training accuracy is: 0.9916323785503982
# At random state 123, the testing accuracy is: -0.1388878276922132
# /n
# At random state 124, the training accuracy is: 0.976778348476541
# At random state 124, the testing accuracy is: 0.20840040025750461
# /n
# At random state 125, the training accuracy is: 0.9899196062996592
# At random state 125, the testing accuracy is: -3.8644092155909426
# /n
# At random state 126, the training accuracy is: 0.9887723325249917
# At random state 126, the testing accuracy is: 0.009320784993262943
# /n
# At random state 127, the training accuracy is: 0.9881345966902991
# At random state 127, the testing accuracy is: -5.363122721934269
# /n
# At random state 128, the training accuracy is: 0.9915558276698994
# At random state 128, the testing accuracy is: -3.8641810712386597
# /n
# At random state 129, the training accuracy is: 0.9778483118687966
# At random state 129, the testing accuracy is: -0.3149781694761782
# /n
# At random state 130, the training accuracy is: 0.9658499970192659
# At random state 130, the testing accuracy is: 0.6569618144544138
# /n
# At random state 131, the training accuracy is: 0.9824857900496613
# At random state 131, the testing accuracy is: -0.04009991199958418
# /n
# At random state 132, the training accuracy is: 0.987708915788322
# At random state 132, the testing accuracy is: 0.6008730227888117
# /n
# At random state 133, the training accuracy is: 0.957601549488937
# At random state 133, the testing accuracy is: 0.4310793836674244
# /n
# At random state 134, the training accuracy is: 0.9674551536440147
# At random state 134, the testing accuracy is: 0.33092992252872233
# /n
# At random state 135, the training accuracy is: 0.9745495153886893
# At random state 135, the testing accuracy is: 0.4735002700088481
# /n
# At random state 136, the training accuracy is: 0.9600528178868206
# At random state 136, the testing accuracy is: 0.8738641106988351
# /n
# At random state 137, the training accuracy is: 0.9483481651837427
# At random state 137, the testing accuracy is: 0.8520355194075246
# /n
# At random state 138, the training accuracy is: 0.9816612226549406
# At random state 138, the testing accuracy is: -1.8677357563210277
# /n
# At random state 139, the training accuracy is: 0.972800900392297
# At random state 139, the testing accuracy is: 0.16721122332096872
# /n
# At random state 140, the training accuracy is: 0.9703607239520605
# At random state 140, the testing accuracy is: 0.6450083447036392
# /n
# At random state 141, the training accuracy is: 0.9843377099339496
# At random state 141, the testing accuracy is: 0.6607123745717665
# /n
# At random state 142, the training accuracy is: 0.9760389257082219
# At random state 142, the testing accuracy is: 0.72207803101465
# /n
# At random state 143, the training accuracy is: 0.9651084675567079
# At random state 143, the testing accuracy is: 0.6105037605958907
# /n
# At random state 144, the training accuracy is: 0.9947134383912125
# At random state 144, the testing accuracy is: 0.5648979174362312
# /n
# At random state 145, the training accuracy is: 0.9886169876152828
# At random state 145, the testing accuracy is: 0.20149631548815405
# /n
# At random state 146, the training accuracy is: 0.9603517219258455
# At random state 146, the testing accuracy is: 0.34194464968060867
# /n
# At random state 147, the training accuracy is: 0.9785952141080665
# At random state 147, the testing accuracy is: 0.32712418687124123
# /n
# At random state 148, the training accuracy is: 0.9618351226775229
# At random state 148, the testing accuracy is: 0.8101303321224822
# /n
# At random state 149, the training accuracy is: 0.969246557428799
# At random state 149, the testing accuracy is: 0.7419900448026033
# /n
# At random state 150, the training accuracy is: 0.9781556173856443
# At random state 150, the testing accuracy is: 0.661905268616416
# /n
# At random state 151, the training accuracy is: 0.9561423354092271
# At random state 151, the testing accuracy is: 0.6197262007699025
# /n
# At random state 152, the training accuracy is: 0.9708036314822869
# At random state 152, the testing accuracy is: 0.6731019986517743
# /n
# At random state 153, the training accuracy is: 0.9723050113916214
# At random state 153, the testing accuracy is: 0.6662976771094411
# /n
# At random state 154, the training accuracy is: 0.9693252708837885
# At random state 154, the testing accuracy is: 0.8387178314689163
# /n
# At random state 155, the training accuracy is: 0.9812810866787344
# At random state 155, the testing accuracy is: 0.6901702603226719
# /n
# At random state 156, the training accuracy is: 0.972200259528267
# At random state 156, the testing accuracy is: 0.6987520786199728
# /n
# At random state 157, the training accuracy is: 0.974090649039092
# At random state 157, the testing accuracy is: 0.6857245778155243
# /n
# At random state 158, the training accuracy is: 0.9846984732975805
# At random state 158, the testing accuracy is: 0.08448827993235164
# /n
# At random state 159, the training accuracy is: 0.9697032199147653
# At random state 159, the testing accuracy is: 0.1364632225075071
# /n
# At random state 160, the training accuracy is: 0.961619619335826
# At random state 160, the testing accuracy is: 0.8082868544022513
# /n
# At random state 161, the training accuracy is: 0.9896594270578057
# At random state 161, the testing accuracy is: -0.21755226044940446
# /n
# At random state 162, the training accuracy is: 0.9675569421338784
# At random state 162, the testing accuracy is: 0.731726474319558
# /n
# At random state 163, the training accuracy is: 0.9872308118591921
# At random state 163, the testing accuracy is: -1.3430472159596856
# /n
# At random state 164, the training accuracy is: 0.9944661653949339
# At random state 164, the testing accuracy is: -0.38193945346365354
# /n
# At random state 165, the training accuracy is: 0.9572574082179057
# At random state 165, the testing accuracy is: 0.873648365829204
# /n
# At random state 166, the training accuracy is: 0.9849471439129687
# At random state 166, the testing accuracy is: -1.473191083564716
# /n
# At random state 167, the training accuracy is: 0.9721906114361965
# At random state 167, the testing accuracy is: 0.6887012758607098
# /n
# At random state 168, the training accuracy is: 0.9437957968740399
# At random state 168, the testing accuracy is: 0.8933237819250966
# /n
# At random state 169, the training accuracy is: 0.9778623121920148
# At random state 169, the testing accuracy is: -2.2982837642759986
# /n
# At random state 170, the training accuracy is: 0.9594127239068765
# At random state 170, the testing accuracy is: 0.6420289956378766
# /n
# At random state 171, the training accuracy is: 0.9886084442200577
# At random state 171, the testing accuracy is: 0.6078511906697306
# /n
# At random state 172, the training accuracy is: 0.9788732274470838
# At random state 172, the testing accuracy is: 0.4814289589262656
# /n
# At random state 173, the training accuracy is: 0.9702995598321686
# At random state 173, the testing accuracy is: 0.8177944837129338
# /n
# At random state 174, the training accuracy is: 0.9928958197859994
# At random state 174, the testing accuracy is: -0.4609181511174494
# /n
# At random state 175, the training accuracy is: 0.9558617970715406
# At random state 175, the testing accuracy is: 0.7902653931519816
# /n
# At random state 176, the training accuracy is: 0.968642927537848
# At random state 176, the testing accuracy is: 0.5358328739233625
# /n
# At random state 177, the training accuracy is: 0.9724855899813843
# At random state 177, the testing accuracy is: -0.8770588165603055
# /n
# At random state 178, the training accuracy is: 0.9691794036547625
# At random state 178, the testing accuracy is: 0.6582652154532374
# /n
# At random state 179, the training accuracy is: 0.9905657896846382
# At random state 179, the testing accuracy is: 0.08010486681820239
# /n
# At random state 180, the training accuracy is: 0.9762127338082879
# At random state 180, the testing accuracy is: 0.7720340290038813
# /n
# At random state 181, the training accuracy is: 0.9637484541453384
# At random state 181, the testing accuracy is: 0.1465572410339756
# /n
# At random state 182, the training accuracy is: 0.9734005926941137
# At random state 182, the testing accuracy is: -1.298436178474304
# /n
# At random state 183, the training accuracy is: 0.9641006566326942
# At random state 183, the testing accuracy is: 0.4764463249617503
# /n
# At random state 184, the training accuracy is: 0.9621506976094386
# At random state 184, the testing accuracy is: -0.4096454477784244
# /n
# At random state 185, the training accuracy is: 0.9820520717185398
# At random state 185, the testing accuracy is: -1.4021199350493339
# /n
# At random state 186, the training accuracy is: 0.9901632501657287
# At random state 186, the testing accuracy is: 0.16400207331059402
# /n
# At random state 187, the training accuracy is: 0.9877559533573526
# At random state 187, the testing accuracy is: 0.22939869265424362
# /n
# At random state 188, the training accuracy is: 0.9665521638884734
# At random state 188, the testing accuracy is: -0.879339031172349
# /n
# At random state 189, the training accuracy is: 0.989677194717221
# At random state 189, the testing accuracy is: 0.3880801932086926
# /n
# At random state 190, the training accuracy is: 0.9899313824550218
# At random state 190, the testing accuracy is: -1.0217557941336857
# /n
# At random state 191, the training accuracy is: 0.9766308805296677
# At random state 191, the testing accuracy is: 0.5663338776694117
# /n
# At random state 192, the training accuracy is: 0.9710655865553208
# At random state 192, the testing accuracy is: 0.6291801135209143
# /n
# At random state 193, the training accuracy is: 0.984988036351699
# At random state 193, the testing accuracy is: -0.32372710845539143
# /n
# At random state 194, the training accuracy is: 0.9879731494098379
# At random state 194, the testing accuracy is: 0.777712828370455
# /n
# At random state 195, the training accuracy is: 0.9846228680220931
# At random state 195, the testing accuracy is: 0.37298473592467307
# /n
# At random state 196, the training accuracy is: 0.9743595423562837
# At random state 196, the testing accuracy is: 0.5982706102290225
# /n
# At random state 197, the training accuracy is: 0.9847060308716394
# At random state 197, the testing accuracy is: 0.05742019280460753
# /n
# At random state 198, the training accuracy is: 0.9858754286075295
# At random state 198, the testing accuracy is: 0.5754820920311714
# /n
# At random state 199, the training accuracy is: 0.982771633349047
# At random state 199, the testing accuracy is: -0.7354362919629835
# /n
# At random state 200, the training accuracy is: 0.9972320852241767
# At random state 200, the testing accuracy is: -0.05487851350076367
# /n
# At random state 201, the training accuracy is: 0.9704111228432925
# At random state 201, the testing accuracy is: 0.6214068326890371
# /n
# At random state 202, the training accuracy is: 0.964496156393102
# At random state 202, the testing accuracy is: 0.39651436827037845
# /n
# At random state 203, the training accuracy is: 0.9611729083232363
# At random state 203, the testing accuracy is: 0.6609442154101192
# /n
# At random state 204, the training accuracy is: 0.9753886040080318
# At random state 204, the testing accuracy is: 0.45619312466167594
# /n
# At random state 205, the training accuracy is: 0.9638142837520096
# At random state 205, the testing accuracy is: 0.7874633031404313
# /n
# At random state 206, the training accuracy is: 0.982564881090792
# At random state 206, the testing accuracy is: 0.40049087071170064
# /n
# At random state 207, the training accuracy is: 0.9873048730567949
# At random state 207, the testing accuracy is: 0.6327230419000102
# /n
# At random state 208, the training accuracy is: 0.9741512439277296
# At random state 208, the testing accuracy is: 0.06511161909614727
# /n
# At random state 209, the training accuracy is: 0.9660254086283879
# At random state 209, the testing accuracy is: 0.7267927929144807
# /n
# At random state 210, the training accuracy is: 0.9860946224266806
# At random state 210, the testing accuracy is: -0.22336838307437068
# /n
# At random state 211, the training accuracy is: 0.9926952784916955
# At random state 211, the testing accuracy is: -0.6887398349246796
# /n
# At random state 212, the training accuracy is: 0.9842445210018729
# At random state 212, the testing accuracy is: 0.4711365505614281
# /n
# At random state 213, the training accuracy is: 0.9821641351224722
# At random state 213, the testing accuracy is: -1.6477568861292275
# /n
# At random state 214, the training accuracy is: 0.9736975281414484
# At random state 214, the testing accuracy is: 0.6656192970196553
# /n
# At random state 215, the training accuracy is: 0.9624006849650034
# At random state 215, the testing accuracy is: -0.02389937308687684
# /n
# At random state 216, the training accuracy is: 0.9771008442442033
# At random state 216, the testing accuracy is: 0.3111255976480979
# /n
# At random state 217, the training accuracy is: 0.9636473394855258
# At random state 217, the testing accuracy is: 0.775818131187803
# /n
# At random state 218, the training accuracy is: 0.9581012212363091
# At random state 218, the testing accuracy is: 0.18582897964888412
# /n
# At random state 219, the training accuracy is: 0.976563575372615
# At random state 219, the testing accuracy is: 0.23424965509604245
# /n
# At random state 220, the training accuracy is: 0.9896784053590758
# At random state 220, the testing accuracy is: 0.2613503578761702
# /n
# At random state 221, the training accuracy is: 0.9913813304139266
# At random state 221, the testing accuracy is: -0.8026081711565893
# /n
# At random state 222, the training accuracy is: 0.9904835659349848
# At random state 222, the testing accuracy is: -0.05719301940491439
# /n
# At random state 223, the training accuracy is: 0.9871036940049386
# At random state 223, the testing accuracy is: -2.6236460175901235
# /n
# At random state 224, the training accuracy is: 0.9412366794234458
# At random state 224, the testing accuracy is: 0.8862950582394856
# /n
# At random state 225, the training accuracy is: 0.9835544335750404
# At random state 225, the testing accuracy is: -0.06737708882603011
# /n
# At random state 226, the training accuracy is: 0.9893031953836458
# At random state 226, the testing accuracy is: 0.5365320202526321
# /n
# At random state 227, the training accuracy is: 0.9877919445028865
# At random state 227, the testing accuracy is: -4.450295957724028
# /n
# At random state 228, the training accuracy is: 0.9867188653314554
# At random state 228, the testing accuracy is: 0.033899968582833284
# /n
# At random state 229, the training accuracy is: 0.9742013747126801
# At random state 229, the testing accuracy is: -0.20855770755979663
# /n
# At random state 230, the training accuracy is: 0.9733831116772774
# At random state 230, the testing accuracy is: -0.22713792633069319
# /n
# At random state 231, the training accuracy is: 0.9751765688387958
# At random state 231, the testing accuracy is: 0.7323730416007195
# /n
# At random state 232, the training accuracy is: 0.972548450191143
# At random state 232, the testing accuracy is: 0.6837424491783939
# /n
# At random state 233, the training accuracy is: 0.987354408631268
# At random state 233, the testing accuracy is: -0.9411393873581566
# /n
# At random state 234, the training accuracy is: 0.9670809113516707
# At random state 234, the testing accuracy is: 0.5871805463303775
# /n
# At random state 235, the training accuracy is: 0.9865702551456557
# At random state 235, the testing accuracy is: 0.06474379961799936
# /n
# At random state 236, the training accuracy is: 0.975923169236618
# At random state 236, the testing accuracy is: -0.0067557383954433
# /n
# At random state 237, the training accuracy is: 0.9723948112625098
# At random state 237, the testing accuracy is: 0.5998750750350929
# /n
# At random state 238, the training accuracy is: 0.9911797154021396
# At random state 238, the testing accuracy is: 0.02625632858964566
# /n
# At random state 239, the training accuracy is: 0.9816337966182648
# At random state 239, the testing accuracy is: 0.5990224594844223
# /n
# At random state 240, the training accuracy is: 0.9530936405472468
# At random state 240, the testing accuracy is: 0.7875397402788671
# /n
# At random state 241, the training accuracy is: 0.9666658779265316
# At random state 241, the testing accuracy is: 0.3974666949986786
# /n
# At random state 242, the training accuracy is: 0.9607514236668943
# At random state 242, the testing accuracy is: 0.5882451441851813
# /n
# At random state 243, the training accuracy is: 0.9651315487156481
# At random state 243, the testing accuracy is: 0.38182356115504335
# /n
# At random state 244, the training accuracy is: 0.9773931308786671
# At random state 244, the testing accuracy is: 0.15403537709930637
# /n
# At random state 245, the training accuracy is: 0.976487164509089
# At random state 245, the testing accuracy is: 0.1735748057094565
# /n
# At random state 246, the training accuracy is: 0.9739832816548467
# At random state 246, the testing accuracy is: 0.5727420395557299
# /n
# At random state 247, the training accuracy is: 0.9654783962230095
# At random state 247, the testing accuracy is: -1.1871272497398548
# /n
# At random state 248, the training accuracy is: 0.9922411766546901
# At random state 248, the testing accuracy is: -0.23797183682267198
# /n
# At random state 249, the training accuracy is: 0.9824125185707048
# At random state 249, the testing accuracy is: 0.7289434897268839
# /n
# At random state 250, the training accuracy is: 0.9948698435610009
# At random state 250, the testing accuracy is: -1.1170047668216045
# /n
# At random state 251, the training accuracy is: 0.9734812467082498
# At random state 251, the testing accuracy is: -0.3212538137229368
# /n
# At random state 252, the training accuracy is: 0.9588004393430778
# At random state 252, the testing accuracy is: 0.7790121352657037
# /n
# At random state 253, the training accuracy is: 0.9705693212268223
# At random state 253, the testing accuracy is: -4.211406757984697
# /n
# At random state 254, the training accuracy is: 0.9773727223716845
# At random state 254, the testing accuracy is: 0.49312833550779755
# /n
# At random state 255, the training accuracy is: 0.9921246798282395
# At random state 255, the testing accuracy is: -1.0413267255888532
# /n
# At random state 256, the training accuracy is: 0.9909079628434356
# At random state 256, the testing accuracy is: -2.1133471407570896
# /n
# At random state 257, the training accuracy is: 0.9966853905385411
# At random state 257, the testing accuracy is: -0.7490266879312111
# /n
# At random state 258, the training accuracy is: 0.9901087027070248
# At random state 258, the testing accuracy is: -0.09883745170832237
# /n
# At random state 259, the training accuracy is: 0.9698909155557429
# At random state 259, the testing accuracy is: 0.30687372964879045
# /n
# At random state 260, the training accuracy is: 0.9739480478700248
# At random state 260, the testing accuracy is: 0.6682286062780081
# /n
# At random state 261, the training accuracy is: 0.989744613250497
# At random state 261, the testing accuracy is: 0.006670010152231454
# /n
# At random state 262, the training accuracy is: 0.9811913857992705
# At random state 262, the testing accuracy is: 0.56188572809478
# /n
# At random state 263, the training accuracy is: 0.980169257384289
# At random state 263, the testing accuracy is: 0.033106013910986665
# /n
# At random state 264, the training accuracy is: 0.9833528968196299
# At random state 264, the testing accuracy is: 0.7292830832013095
# /n
# At random state 265, the training accuracy is: 0.9603722588422469
# At random state 265, the testing accuracy is: 0.7556967619970296
# /n
# At random state 266, the training accuracy is: 0.9578486988999295
# At random state 266, the testing accuracy is: 0.5840221832114036
# /n
# At random state 267, the training accuracy is: 0.9608603105617496
# At random state 267, the testing accuracy is: 0.5169033616088943
# /n
# At random state 268, the training accuracy is: 0.9841388245694216
# At random state 268, the testing accuracy is: -0.34253005586862306
# /n
# At random state 269, the training accuracy is: 0.9828715152753157
# At random state 269, the testing accuracy is: 0.5989798488114532
# /n
# At random state 270, the training accuracy is: 0.9958781310457837
# At random state 270, the testing accuracy is: 0.6571068851453916
# /n
# At random state 271, the training accuracy is: 0.9647912764963287
# At random state 271, the testing accuracy is: 0.3032262836543781
# /n
# At random state 272, the training accuracy is: 0.9663086964723127
# At random state 272, the testing accuracy is: 0.5028052405703605
# /n
# At random state 273, the training accuracy is: 0.9568158108748758
# At random state 273, the testing accuracy is: 0.8667339268748606
# /n
# At random state 274, the training accuracy is: 0.9702698564676734
# At random state 274, the testing accuracy is: 0.3828906190632225
# /n
# At random state 275, the training accuracy is: 0.9912951730406786
# At random state 275, the testing accuracy is: -1.7924452438773768
# /n
# At random state 276, the training accuracy is: 0.9593966703146342
# At random state 276, the testing accuracy is: 0.6791834948900854
# /n
# At random state 277, the training accuracy is: 0.9744092734566769
# At random state 277, the testing accuracy is: 0.4013287828429073
# /n
# At random state 278, the training accuracy is: 0.9767125721182407
# At random state 278, the testing accuracy is: 0.32983011773988835
# /n
# At random state 279, the training accuracy is: 0.9806164989335716
# At random state 279, the testing accuracy is: 0.542328765532953
# /n
# At random state 280, the training accuracy is: 0.9545153667510134
# At random state 280, the testing accuracy is: 0.7827425410008184
# /n
# At random state 281, the training accuracy is: 0.9675665310907985
# At random state 281, the testing accuracy is: 0.1945865467415938
# /n
# At random state 282, the training accuracy is: 0.9860541422817626
# At random state 282, the testing accuracy is: 0.49913667966970887
# /n
# At random state 283, the training accuracy is: 0.9914734507977291
# At random state 283, the testing accuracy is: -2.4855924935684475
# /n
# At random state 284, the training accuracy is: 0.9755703176445286
# At random state 284, the testing accuracy is: 0.3062093341528329
# /n
# At random state 285, the training accuracy is: 0.9612156456012569
# At random state 285, the testing accuracy is: 0.7963237779560066
# /n
# At random state 286, the training accuracy is: 0.9633003546495515
# At random state 286, the testing accuracy is: 0.5872973866118374
# /n
# At random state 287, the training accuracy is: 0.9621222067788239
# At random state 287, the testing accuracy is: 0.7077289060905816
# /n
# At random state 288, the training accuracy is: 0.9807594904675093
# At random state 288, the testing accuracy is: 0.7730618788685515
# /n
# At random state 289, the training accuracy is: 0.9903424957996096
# At random state 289, the testing accuracy is: 0.08024657274151614
# /n
# At random state 290, the training accuracy is: 0.981720318991406
# At random state 290, the testing accuracy is: 0.7509448289554753
# /n
# At random state 291, the training accuracy is: 0.976203564346951
# At random state 291, the testing accuracy is: 0.5117562310165291
# /n
# At random state 292, the training accuracy is: 0.9898722296227717
# At random state 292, the testing accuracy is: 0.3816517326942833
# /n
# At random state 293, the training accuracy is: 0.9957314532336417
# At random state 293, the testing accuracy is: 0.16962815663356745
# /n
# At random state 294, the training accuracy is: 0.9733314917567558
# At random state 294, the testing accuracy is: 0.7719908714321322
# /n
# At random state 295, the training accuracy is: 0.9878299489367078
# At random state 295, the testing accuracy is: 0.4975163463859179
# /n
# At random state 296, the training accuracy is: 0.9668347917847668
# At random state 296, the testing accuracy is: 0.574194747438636
# /n
# At random state 297, the training accuracy is: 0.9595805617731551
# At random state 297, the testing accuracy is: 0.8869374823877922
# /n
# At random state 298, the training accuracy is: 0.9658879458845091
# At random state 298, the testing accuracy is: 0.523506733970195
# /n
# At random state 299, the training accuracy is: 0.9945891412092287
# At random state 299, the testing accuracy is: -1.6091076183953432
# /n
# At random state 300, the training accuracy is: 0.9923663672386219
# At random state 300, the testing accuracy is: -0.817323080153473
# /n
# At random state 301, the training accuracy is: 0.9628695538530523
# At random state 301, the testing accuracy is: 0.7411682529450112
# /n
# At random state 302, the training accuracy is: 0.979874252676784
# At random state 302, the testing accuracy is: -1.4307096786588915
# /n
# At random state 303, the training accuracy is: 0.9699945847369895
# At random state 303, the testing accuracy is: 0.8042036502124742
# /n
# At random state 304, the training accuracy is: 0.931872424787973
# At random state 304, the testing accuracy is: 0.8906242612507713
# /n
# At random state 305, the training accuracy is: 0.9694952164422606
# At random state 305, the testing accuracy is: -0.31947093269655036
# /n
# At random state 306, the training accuracy is: 0.9908423970091342
# At random state 306, the testing accuracy is: -0.8993198796171242
# /n
# At random state 307, the training accuracy is: 0.9672496462977702
# At random state 307, the testing accuracy is: 0.5417318268278295
# /n
# At random state 308, the training accuracy is: 0.9840081072144271
# At random state 308, the testing accuracy is: 0.37472859676775716
# /n
# At random state 309, the training accuracy is: 0.9867994043412172
# At random state 309, the testing accuracy is: -2.8072263661019927
# /n
# At random state 310, the training accuracy is: 0.9554329086337005
# At random state 310, the testing accuracy is: 0.0834544379766583
# /n
# At random state 311, the training accuracy is: 0.9802529777060576
# At random state 311, the testing accuracy is: 0.7487820670307972
# /n
# At random state 312, the training accuracy is: 0.9689581867525637
# At random state 312, the testing accuracy is: -2.1976706726710975
# /n
# At random state 313, the training accuracy is: 0.9786145840833279
# At random state 313, the testing accuracy is: 0.2887501851646518
# /n
# At random state 314, the training accuracy is: 0.9857995684408127
# At random state 314, the testing accuracy is: -1.0606561024742809
# /n
# At random state 315, the training accuracy is: 0.9696641493214586
# At random state 315, the testing accuracy is: 0.7401626277012401
# /n
# At random state 316, the training accuracy is: 0.9810000705007788
# At random state 316, the testing accuracy is: -1.53973465643451
# /n
# At random state 317, the training accuracy is: 0.9805311776090776
# At random state 317, the testing accuracy is: 0.23888986624519648
# /n
# At random state 318, the training accuracy is: 0.9898136579942437
# At random state 318, the testing accuracy is: 0.5208498592728502
# /n
# At random state 319, the training accuracy is: 0.9864336443791324
# At random state 319, the testing accuracy is: -1.422579761854728
# /n
# At random state 320, the training accuracy is: 0.9846588809715502
# At random state 320, the testing accuracy is: 0.814216028923523
# /n
# At random state 321, the training accuracy is: 0.9692406651654757
# At random state 321, the testing accuracy is: -2.957345534610051
# /n
# At random state 322, the training accuracy is: 0.9858572820261969
# At random state 322, the testing accuracy is: 0.5431596983187827
# /n
# At random state 323, the training accuracy is: 0.9863491407152337
# At random state 323, the testing accuracy is: 0.24255840843340182
# /n
# At random state 324, the training accuracy is: 0.9838697074495273
# At random state 324, the testing accuracy is: 0.4700251446166501
# /n
# At random state 325, the training accuracy is: 0.9629998432445012
# At random state 325, the testing accuracy is: 0.7187557879049521
# /n
# At random state 326, the training accuracy is: 0.9844466458362883
# At random state 326, the testing accuracy is: -1.16466671682184
# /n
# At random state 327, the training accuracy is: 0.9651849368173655
# At random state 327, the testing accuracy is: -0.1081496659113379
# /n
# At random state 328, the training accuracy is: 0.9788762410905779
# At random state 328, the testing accuracy is: 0.03998280819916378
# /n
# At random state 329, the training accuracy is: 0.9742538695293462
# At random state 329, the testing accuracy is: -1.4932157942036084
# /n
# At random state 330, the training accuracy is: 0.9869939770234344
# At random state 330, the testing accuracy is: -4.711936083711071
# /n
# At random state 331, the training accuracy is: 0.9895176660941389
# At random state 331, the testing accuracy is: 0.4810349428913503
# /n
# At random state 332, the training accuracy is: 0.9412791794981605
# At random state 332, the testing accuracy is: 0.7908120274478926
# /n
# At random state 333, the training accuracy is: 0.9628270113868717
# At random state 333, the testing accuracy is: 0.6942357831285677
# /n
# At random state 334, the training accuracy is: 0.9700668142726023
# At random state 334, the testing accuracy is: 0.42107195188539426
# /n
# At random state 335, the training accuracy is: 0.9684963891575312
# At random state 335, the testing accuracy is: 0.08454135256533135
# /n
# At random state 336, the training accuracy is: 0.9864842709691789
# At random state 336, the testing accuracy is: -0.07188247364502298
# /n
# At random state 337, the training accuracy is: 0.9691361634344765
# At random state 337, the testing accuracy is: 0.6446059693280616
# /n
# At random state 338, the training accuracy is: 0.996191885243163
# At random state 338, the testing accuracy is: -3.490412390629121
# /n
# At random state 339, the training accuracy is: 0.97121579549817
# At random state 339, the testing accuracy is: 0.657270180083521
# /n
# At random state 340, the training accuracy is: 0.9746374213879306
# At random state 340, the testing accuracy is: 0.6163601931617584
# /n
# At random state 341, the training accuracy is: 0.9754937771039718
# At random state 341, the testing accuracy is: 0.5318231609665696
# /n
# At random state 342, the training accuracy is: 0.9541485311591641
# At random state 342, the testing accuracy is: 0.6054942306625821
# /n
# At random state 343, the training accuracy is: 0.962962736625695
# At random state 343, the testing accuracy is: 0.8606785018613325
# /n
# At random state 344, the training accuracy is: 0.9654996340414397
# At random state 344, the testing accuracy is: 0.4411821141867843
# /n
# At random state 345, the training accuracy is: 0.9813695350591561
# At random state 345, the testing accuracy is: 0.5890928436060804
# /n
# At random state 346, the training accuracy is: 0.975137638142759
# At random state 346, the testing accuracy is: 0.6130881172032965
# /n
# At random state 347, the training accuracy is: 0.9618764429915432
# At random state 347, the testing accuracy is: 0.5683270315683318
# /n
# At random state 348, the training accuracy is: 0.9877319757504188
# At random state 348, the testing accuracy is: -0.9107812522264211
# /n
# At random state 349, the training accuracy is: 0.9786553289619965
# At random state 349, the testing accuracy is: 0.21067762397012468
# /n
# At random state 350, the training accuracy is: 0.9704744979397779
# At random state 350, the testing accuracy is: 0.6391287359276236
# /n
# At random state 351, the training accuracy is: 0.98021371162347
# At random state 351, the testing accuracy is: 0.36704289658229905
# /n
# At random state 352, the training accuracy is: 0.9836705555201092
# At random state 352, the testing accuracy is: 0.6625018010293244
# /n
# At random state 353, the training accuracy is: 0.9698175992326542
# At random state 353, the testing accuracy is: 0.7638007819722213
# /n
# At random state 354, the training accuracy is: 0.9939694937112992
# At random state 354, the testing accuracy is: 0.3595303480217933
# /n
# At random state 355, the training accuracy is: 0.9853971344485877
# At random state 355, the testing accuracy is: 0.1498639546642423
# /n
# At random state 356, the training accuracy is: 0.9652041037411228
# At random state 356, the testing accuracy is: 0.44527455337983823
# /n
# At random state 357, the training accuracy is: 0.9780391593558795
# At random state 357, the testing accuracy is: 0.5402640974836359
# /n
# At random state 358, the training accuracy is: 0.9677431643417252
# At random state 358, the testing accuracy is: 0.6865953346711
# /n
# At random state 359, the training accuracy is: 0.985841795159035
# At random state 359, the testing accuracy is: -0.47328596184951954
# /n
# ...
# /n
# At random state 381, the training accuracy is: 0.9547537020235554
# At random state 381, the testing accuracy is: 0.8422473024882259
# /n
# At random state 382, the training accuracy is: 0.9826303901496689
# At random state 382, the testing accuracy is: 0.2594501668982646
# /n
# At random state 383, the training accuracy is: 0.9705646334045801
# At random state 383, the testing accuracy is: 0.6930675691819712
# /n
# At random state 384, the training accuracy is: 0.9651971942101671
# At random state 384, the testing accuracy is: 0.7371378421862382
# /n
# At random state 385, the training accuracy is: 0.9620880321567774
# At random state 385, the testing accuracy is: 0.7726058577088533
# /n
# At random state 386, the training accuracy is: 0.9802770316446678
# At random state 386, the testing accuracy is: -0.07398006350820263
# /n
# At random state 387, the training accuracy is: 0.9959795127733699
# At random state 387, the testing accuracy is: 0.3283981779209195
# /n
# At random state 388, the training accuracy is: 0.9824880155230993
# At random state 388, the testing accuracy is: -0.3006372760517402
# /n
# At random state 389, the training accuracy is: 0.9978569214667578
# At random state 389, the testing accuracy is: 0.34478364622971425
# /n
# At random state 390, the training accuracy is: 0.9751215462889032
# At random state 390, the testing accuracy is: 0.1968108249230639
# /n
# At random state 391, the training accuracy is: 0.9852528488728182
# At random state 391, the testing accuracy is: 0.18000543347862674
# /n
# At random state 392, the training accuracy is: 0.9761020725621735
# At random state 392, the testing accuracy is: 0.6960906079856046
# /n
# At random state 393, the training accuracy is: 0.9797989420087557
# At random state 393, the testing accuracy is: -0.19197310900462528
# /n
# At random state 394, the training accuracy is: 0.9805334222034677
# At random state 394, the testing accuracy is: 0.7341007939748565
# /n
# At random state 395, the training accuracy is: 0.9738332277083539
# At random state 395, the testing accuracy is: -0.11344540524885094
# /n
# At random state 396, the training accuracy is: 0.982232941832256
# At random state 396, the testing accuracy is: 0.5996549258439858
# /n
# At random state 397, the training accuracy is: 0.978959370564032
# At random state 397, the testing accuracy is: -1.9645658977547846
# /n
# At random state 398, the training accuracy is: 0.9817604241541786
# At random state 398, the testing accuracy is: -0.14669923229147153
# /n
# At random state 399, the training accuracy is: 0.9772137781506032
# At random state 399, the testing accuracy is: 0.7038160002973168
# /n
# At random state 400, the training accuracy is: 0.9873353407888606
# At random state 400, the testing accuracy is: 0.48645760100269386
# /n
# At random state 401, the training accuracy is: 0.9812351770210878
# At random state 401, the testing accuracy is: -0.44375583392373086
# /n
# At random state 402, the training accuracy is: 0.9817457494465606
# At random state 402, the testing accuracy is: 0.5431034074758113
# /n
# At random state 403, the training accuracy is: 0.9897207923668631
# At random state 403, the testing accuracy is: -2.8954372755135953
# /n
# At random state 404, the training accuracy is: 0.9715816180321152
# At random state 404, the testing accuracy is: 0.49826156025791857
# /n
# At random state 405, the training accuracy is: 0.9778033062997994
# At random state 405, the testing accuracy is: -2.120928200290921
# /n
# At random state 406, the training accuracy is: 0.9889278338680215
# At random state 406, the testing accuracy is: 0.38224624698012566
# /n
# At random state 407, the training accuracy is: 0.9667889947110451
# At random state 407, the testing accuracy is: 0.29823013454029756
# /n
# At random state 408, the training accuracy is: 0.9880821491182491
# At random state 408, the testing accuracy is: 0.4311553661661226
# /n
# At random state 409, the training accuracy is: 0.9418258001126429
# At random state 409, the testing accuracy is: 0.7765608200295202
# /n
# At random state 410, the training accuracy is: 0.9758310772194374
# At random state 410, the testing accuracy is: 0.7940782106270025
# /n
# At random state 411, the training accuracy is: 0.9785422345475095
# At random state 411, the testing accuracy is: 0.38192031091548495
# /n
# At random state 412, the training accuracy is: 0.9960110884001121
# At random state 412, the testing accuracy is: -0.9462637559456104
# /n
# At random state 413, the training accuracy is: 0.9646344179668689
# At random state 413, the testing accuracy is: 0.17331491668523058
# /n
# At random state 414, the training accuracy is: 0.9970458415187664
# At random state 414, the testing accuracy is: -1.3718308520376397
# /n
# At random state 415, the training accuracy is: 0.9665517577609859
# At random state 415, the testing accuracy is: 0.338220670636867
# /n
# At random state 416, the training accuracy is: 0.993243649180966
# At random state 416, the testing accuracy is: 0.4111050760860978
# /n
# At random state 417, the training accuracy is: 0.9784220609390739
# At random state 417, the testing accuracy is: -3.1141824003732035
# /n
# At random state 418, the training accuracy is: 0.9746315817385659
# At random state 418, the testing accuracy is: 0.26023985968010577
# /n
# At random state 419, the training accuracy is: 0.9802808741705672
# At random state 419, the testing accuracy is: -10.537232365940149
# /n
# At random state 420, the training accuracy is: 0.9828748110862141
# At random state 420, the testing accuracy is: 0.7483300521441424
# /n
# At random state 421, the training accuracy is: 0.9749909187737718
# At random state 421, the testing accuracy is: 0.7831105139716193
# /n
# At random state 422, the training accuracy is: 0.9831671149275202
# At random state 422, the testing accuracy is: 0.38401453737757574
# /n
# At random state 423, the training accuracy is: 0.9705230540564684
# At random state 423, the testing accuracy is: 0.26182389780567106
# /n
# At random state 424, the training accuracy is: 0.9657428134307315
# At random state 424, the testing accuracy is: 0.13127943271057152
# /n
# At random state 425, the training accuracy is: 0.9946581142202305
# At random state 425, the testing accuracy is: -4.978255389911805
# /n
# At random state 426, the training accuracy is: 0.9591739432171771
# At random state 426, the testing accuracy is: 0.8389835715283176
# /n
# At random state 427, the training accuracy is: 0.9690124731150668
# At random state 427, the testing accuracy is: 0.5138758100047756
# /n
# At random state 428, the training accuracy is: 0.9689692792546116
# At random state 428, the testing accuracy is: 0.5278783394986679
# /n
# At random state 429, the training accuracy is: 0.955613205077165
# At random state 429, the testing accuracy is: 0.6554453997317363
# /n
# At random state 430, the training accuracy is: 0.9345058826947783
# At random state 430, the testing accuracy is: 0.8504107288488434
# /n
# At random state 431, the training accuracy is: 0.9839780949578372
# At random state 431, the testing accuracy is: -4.676474706685708
# /n
# At random state 432, the training accuracy is: 0.9769829849586588
# At random state 432, the testing accuracy is: -0.19586287631036248
# /n
# At random state 433, the training accuracy is: 0.9808547799049112
# At random state 433, the testing accuracy is: -0.22490716595785654
# /n
# At random state 434, the training accuracy is: 0.9731878155054137
# At random state 434, the testing accuracy is: 0.6469608822767825
# /n
# At random state 435, the training accuracy is: 0.9840337145027408
# At random state 435, the testing accuracy is: -0.15690062182191666
# /n
# At random state 436, the training accuracy is: 0.985401785860589
# At random state 436, the testing accuracy is: 0.44575541371153893
# /n
# At random state 437, the training accuracy is: 0.9772674609251469
# At random state 437, the testing accuracy is: 0.47892736697953486
# /n
# At random state 438, the training accuracy is: 0.9695518765792168
# At random state 438, the testing accuracy is: -0.6901317259237183
# /n
# At random state 439, the training accuracy is: 0.9816541773039403
# At random state 439, the testing accuracy is: -0.26124700590557315
# /n
# At random state 440, the training accuracy is: 0.9732003033192711
# At random state 440, the testing accuracy is: 0.34639155652614495
# /n
# At random state 441, the training accuracy is: 0.9522751288459032
# At random state 441, the testing accuracy is: 0.742797601418735
# /n
# At random state 442, the training accuracy is: 0.982063556802616
# At random state 442, the testing accuracy is: -2.802247782028889
# /n
# At random state 443, the training accuracy is: 0.9764921886348159
# At random state 443, the testing accuracy is: -0.8939185944252295
# /n
# At random state 444, the training accuracy is: 0.9638322752065044
# At random state 444, the testing accuracy is: 0.6394509462458857
# /n
# At random state 445, the training accuracy is: 0.9628523679803945
# At random state 445, the testing accuracy is: 0.7607332221208878
# /n
# At random state 446, the training accuracy is: 0.9706771502686744
# At random state 446, the testing accuracy is: 0.6659590454092184
# /n
# At random state 447, the training accuracy is: 0.9638441229456977
# At random state 447, the testing accuracy is: 0.7293637917892162
# /n
# At random state 448, the training accuracy is: 0.9839794764380092
# At random state 448, the testing accuracy is: -1.9461393730768544
# /n
# At random state 449, the training accuracy is: 0.9929457601454104
# At random state 449, the testing accuracy is: -0.12511407102121486
# /n
# At random state 450, the training accuracy is: 0.9652288751192539
# At random state 450, the testing accuracy is: 0.8445642328081666
# /n
# At random state 451, the training accuracy is: 0.9858541227597805
# At random state 451, the testing accuracy is: 0.0666802790982054
# /n
# At random state 452, the training accuracy is: 0.9775154573575445
# At random state 452, the testing accuracy is: -1.8016388466366307
# /n
# At random state 453, the training accuracy is: 0.9587890313672387
# At random state 453, the testing accuracy is: 0.8269899850067185
# /n
# At random state 454, the training accuracy is: 0.9520565093387453
# At random state 454, the testing accuracy is: 0.7697168994853789
# /n
# At random state 455, the training accuracy is: 0.9877270596728501
# At random state 455, the testing accuracy is: -4.392358368901015
# /n
# At random state 456, the training accuracy is: 0.9441249461612262
# At random state 456, the testing accuracy is: 0.827420268799032
# /n
# At random state 457, the training accuracy is: 0.9941021876713995
# At random state 457, the testing accuracy is: -1.281002153325303
# /n
# At random state 458, the training accuracy is: 0.9840615746347608
# At random state 458, the testing accuracy is: 0.7693314574028023
# /n
# At random state 459, the training accuracy is: 0.9555438120356509
# At random state 459, the testing accuracy is: 0.6726574057031541
# /n
# At random state 460, the training accuracy is: 0.9892681202364881
# At random state 460, the testing accuracy is: -3.374925488926263
# /n
# At random state 461, the training accuracy is: 0.9934746092827554
# At random state 461, the testing accuracy is: -0.02922554788099152
# /n
# At random state 462, the training accuracy is: 0.9909099445036563
# At random state 462, the testing accuracy is: -1.13352113795316
# /n
# At random state 463, the training accuracy is: 0.9796463264915269
# At random state 463, the testing accuracy is: 0.7167379553925417
# /n
# At random state 464, the training accuracy is: 0.9640713628364128
# At random state 464, the testing accuracy is: 0.6602116705674677
# /n
# At random state 465, the training accuracy is: 0.9786284109373452
# At random state 465, the testing accuracy is: 0.7846856862424042
# /n
# At random state 466, the training accuracy is: 0.9790034481015766
# At random state 466, the testing accuracy is: 0.19597473149392197
# /n
# At random state 467, the training accuracy is: 0.9825012675402018
# At random state 467, the testing accuracy is: -0.6784771034516146
# /n
# At random state 468, the training accuracy is: 0.9980525472459512
# At random state 468, the testing accuracy is: -3.032650753308645
# /n
# At random state 469, the training accuracy is: 0.9721346553575033
# At random state 469, the testing accuracy is: 0.753477008323521
# /n
# At random state 470, the training accuracy is: 0.9660962753153335
# At random state 470, the testing accuracy is: -3.15538740141739
# /n
# At random state 471, the training accuracy is: 0.9967786354557094
# At random state 471, the testing accuracy is: -3.514709496922505
# /n
# At random state 472, the training accuracy is: 0.9818000604298945
# At random state 472, the testing accuracy is: -2.0749748385947733
# /n
# At random state 473, the training accuracy is: 0.98941079883512
# At random state 473, the testing accuracy is: 0.3115307222378101
# /n
# At random state 474, the training accuracy is: 0.9710608921770911
# At random state 474, the testing accuracy is: 0.698267241937393
# /n
# At random state 475, the training accuracy is: 0.981214398940566
# At random state 475, the testing accuracy is: -1.0779412784325197
# /n
# At random state 476, the training accuracy is: 0.9770195326469957
# At random state 476, the testing accuracy is: 0.5045127620505643
# /n
# At random state 477, the training accuracy is: 0.976026760717848
# At random state 477, the testing accuracy is: -2.864829705613428
# /n
# At random state 478, the training accuracy is: 0.9608327212457901
# At random state 478, the testing accuracy is: 0.6151639445564132
# /n
# At random state 479, the training accuracy is: 0.9649765528329761
# At random state 479, the testing accuracy is: 0.5447880364529971
# /n
# At random state 480, the training accuracy is: 0.9934562178300028
# At random state 480, the testing accuracy is: -0.10704600726852131
# /n
# At random state 481, the training accuracy is: 0.9906685727731446
# At random state 481, the testing accuracy is: -0.27687580744621054
# /n
# At random state 482, the training accuracy is: 0.9720230288960124
# At random state 482, the testing accuracy is: 0.6697607937255776
# /n
# At random state 483, the training accuracy is: 0.9875291229108858
# At random state 483, the testing accuracy is: -9.1894802314862
# /n
# At random state 484, the training accuracy is: 0.9902791649368122
# At random state 484, the testing accuracy is: -1.4414663980750735
# /n
# At random state 485, the training accuracy is: 0.9859542592264665
# At random state 485, the testing accuracy is: -1.8558875723765125
# /n
# At random state 486, the training accuracy is: 0.9690102745218737
# At random state 486, the testing accuracy is: 0.5224377233600532
# /n
# At random state 487, the training accuracy is: 0.9676260252206634
# At random state 487, the testing accuracy is: 0.6186739620533558
# /n
# At random state 488, the training accuracy is: 0.9897769230582429
# At random state 488, the testing accuracy is: 0.3293475475240303
# /n
# At random state 489, the training accuracy is: 0.9503285425299002
# At random state 489, the testing accuracy is: 0.5977238387493937
# /n
# At random state 490, the training accuracy is: 0.9942159115745413
# At random state 490, the testing accuracy is: -4.322711231494677
# /n
# At random state 491, the training accuracy is: 0.9769686370357226
# At random state 491, the testing accuracy is: 0.4744137628192655
# /n
# At random state 492, the training accuracy is: 0.9841055566881369
# At random state 492, the testing accuracy is: 0.034114055265535126
# /n
# At random state 493, the training accuracy is: 0.9577624127045345
# At random state 493, the testing accuracy is: 0.3487346543187929
# /n
# At random state 494, the training accuracy is: 0.9633097304976374
# At random state 494, the testing accuracy is: 0.35145513897973735
# /n
# At random state 495, the training accuracy is: 0.9411949838345999
# At random state 495, the testing accuracy is: 0.9112875836016393
# /n
# At random state 496, the training accuracy is: 0.9713829772736786
# At random state 496, the testing accuracy is: 0.8108895181292152
# /n
# At random state 497, the training accuracy is: 0.9774446343990405
# At random state 497, the testing accuracy is: -0.1472962821834627
# /n
# At random state 498, the training accuracy is: 0.9906528894317819
# At random state 498, the testing accuracy is: 0.24526423780659323
# /n
# At random state 499, the training accuracy is: 0.9950223512272617
# At random state 499, the testing accuracy is: -0.48921754652256455
# /n

# %%
print('Maximum r2',MaxAcc,'Random state: ',MaxRS)
# Out:
# Maximum r2 0.9112875836016393 Random state:  495

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=495)

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)

predlr_test= lr.predict(x_test)
print('r2 score', r2_score(y_test,predlr_test))
print('MAE', mean_absolute_error(y_test,predlr_test))
print('MSE',mean_squared_error(y_test,predlr_test))
print('RNSE',np.sqrt(mean_squared_error(y_test,predlr_test)))
# Out:
# r2 score 0.8651396242565652
# MAE 3.6980356322140366
# MSE 20.622399124100234
# RNSE 4.541189175106036

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
rf= RandomForestRegressor()
rf.fit(x_train,y_train)

predrf_test= rf.predict(x_test)
print('r2 score', r2_score(y_test,predrf_test))
print('MAE', mean_absolute_error(y_test,predrf_test))
print('MSE',mean_squared_error(y_test,predrf_test))
print('RNSE',np.sqrt(mean_squared_error(y_test,predrf_test)))
# Out:
# r2 score 0.6124761852861038
# MAE 6.711666666666666
# MSE 59.25884999999997
# RNSE 7.6979770069804685

# %%
ada= AdaBoostRegressor()
ada.fit(x_train,y_train)

predada= ada.predict(x_test)
print('r2 score', r2_score(y_test,predada))
print('MAE', mean_absolute_error(y_test,predada))
print('MSE',mean_squared_error(y_test,predada))
print('RNSE',np.sqrt(mean_squared_error(y_test,predada)))
# Out:
# r2 score 0.6380002085302786
# MAE 6.382738095238094
# MSE 55.35580144557823
# RNSE 7.440147945140488

# %%
gr= GradientBoostingRegressor()
gr.fit(x_train,y_train)

predgr= gr.predict(x_test)
print('r2 score', r2_score(y_test,predgr))
print('MAE', mean_absolute_error(y_test,predgr))
print('MSE',mean_squared_error(y_test,predgr))
print('RNSE',np.sqrt(mean_squared_error(y_test,predgr)))
# Out:
# r2 score 0.4869545919255237
# MAE 8.167797225314715
# MSE 78.45319365138867
# RNSE 8.857380744406818

# %% [markdown]
# ## Regularization

# %%
from sklearn.linear_model import Ridge
ridgeR= Ridge(alpha=1)
ridgeR.fit(x_train,y_train)
y_pred =ridgeR.predict(x_test)
print('r2 score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('RNSE',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score 0.792101530188226
# MAE 4.720740858746019
# MSE 31.791141008717094
# RNSE 5.638363327129345

# %%
from sklearn.linear_model import Lasso
Lasso= Lasso(alpha=1)
Lasso.fit(x_train,y_train)
y_pred =Lasso.predict(x_test)
print('r2 score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('RNSE',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score 0.785128186814207
# MAE 4.9471636214175305
# MSE 32.85748143299418
# RNSE 5.732144575374401

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
Test_accuracy =r2_score(y_test,y_pred)

for j in range(2,10):
    cv_score=cross_val_score(ridgeR,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At fold {j} the cv score is {cv_mean} and accuracy score for testing is {Test_accuracy} ')
    print('\n')
# Out:
# At fold 2 the cv score is 0.6972587676590756 and accuracy score for testing is 0.792101530188226
#
#
# At fold 3 the cv score is 0.5400920139159089 and accuracy score for testing is 0.792101530188226
#
#
# At fold 4 the cv score is 0.5961354365006584 and accuracy score for testing is 0.792101530188226
#
#
# At fold 5 the cv score is 0.44416049884769004 and accuracy score for testing is 0.792101530188226
#
#
# At fold 6 the cv score is 0.41874561303230123 and accuracy score for testing is 0.792101530188226
#
#
# At fold 7 the cv score is 0.29258115460521644 and accuracy score for testing is 0.792101530188226
#
#
# At fold 8 the cv score is 0.43851208339209174 and accuracy score for testing is 0.792101530188226
#
#
# At fold 9 the cv score is -6.327125544222607 and accuracy score for testing is 0.792101530188226

# %%
a = cross_val_score(lr,x,y,cv=9)
print('Cross validation score of Logistic Regression',a.mean())
# Out:
# Cross validation score of Logistic Regression -13.02980660220171

# %%
b = cross_val_score(rf,x,y,cv=9)
print('Cross validation score of Random Forest Classifier',b.mean())
# Out:
# Cross validation score of Random Forest Classifier -11.684084538418853

# %% [markdown]
# Ridge was selected as the best model as it had better  r2 score and cross validation score

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params ={'alpha':(np.logspace(-8,8,100))}
ridgeR= Ridge(normalize= True)
ridge_model = GridSearchCV(ridgeR,params,cv=2)
ridge_model.fit(x_train,y_train)
print(ridge_model.best_params_)
print(ridge_model.best_score_)
# Out:
# {'alpha': 0.8302175681319752}
# 0.7282139396208269

# %% [markdown]
# ## Saving Model

# %%
import joblib

# %%
joblib.dump(ridge_model,'BaseballCaseStudy.pkl')
# Out:
# ['BaseballCaseStudy.pkl']
